# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install localtunnel@2.0.2
# Out:
# Collecting localtunnel@ 2.0.2
# ERROR: Could not install packages due to an OSError: Invalid URL '2.0.2': No scheme supplied. Perhaps you meant https://2.0.2?

# %%
# !pip install -q streamlit

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.42.160.11

# %%
! streamlit run /content/drive/MyDrive/practice/ipl_score_predictor_jb.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.42.160.11:8501
#
# ⠼⠴your url is: https://large-dragons-go.loca.lt
